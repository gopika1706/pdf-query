# %% [markdown]
# ## PDF Query Using Langchain

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install langchain
# !pip install openai
# !pip install PyPDF2
# !pip install faiss-cpu
# !pip install tiktoken

# %%
import os

# %%
os.getenv('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')

# %%
os.environ["OPENAI_API_KEY"]='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'

# %%
from PyPDF2 import PdfReader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import FAISS

# %%
#import os
#os.environ["OPENAI_API_KEY"] = ""
#os.environ["SERPAPI_API_KEY"] = ""

# %%
# provide the path of  pdf file/files.
pdfreader = PdfReader('random forest.pdf')

# %%
from typing_extensions import Concatenate
# read text from pdf
raw_text = ''
for i, page in enumerate(pdfreader.pages):
    content = page.extract_text()
    if content:
        raw_text += content

# %%
raw_text
# Out:
# 'Random \nForest\nWhat is a Random \nForest?\nRandom forest is a commonly-used machine \nlearning algorithm used for both classification \nand regression tasks. It combines the output of \nmultiple decision trees to reach a single result.\nRandom forest is a flexible, easy-to-use machine \nlearning algorithm that produces, even without \nhyper-parameter tuning, a great result most of \nthe time. It is also less prone to overfitting \ncompared to individual decision trees.\nEnsemble learning:  Ensemble learning refers to \nthe technique of combining multiple models to \nimprove overall performance. Random Forest is \nan ensemble learning method that combines \nmultiple decision trees.\nHyperparameters:  Random Forest has several \nhyperparameters that can be tuned to optimize \nits performance, such as the number of decision \ntrees in the ensemble, the maximum depth of \neach tree, and the number of features considered \nat each split.Key Terms\nBagging:  Bagging stands for Bootstrap
# ...

# %%
# We need to split the text using Character Text Split such that it sshould not increse token size
text_splitter = CharacterTextSplitter(
    separator = "\n",
    chunk_size = 800,
    chunk_overlap  = 200,
    length_function = len,
)
texts = text_splitter.split_text(raw_text)

# %%
len(texts)
# Out:
# 12

# %%
import openai

# %%
#!pip install openai[embeddings]

# %%
#openai.api_key = "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"

# %%
# Download embeddings from OpenAI
#embeddings = OpenAIEmbeddings(openai_api_key=openai.api_key)
embeddings = OpenAIEmbeddings()

# %%
document_search = FAISS.from_texts(texts, embeddings)

# %%
document_search

# %%
from langchain.chains.question_answering import load_qa_chain
from langchain.llms import OpenAI

# %%
chain = load_qa_chain(OpenAI(openai_api_key=openai.api_key), chain_type="stuff")

# %%
query = "what is random forest"
docs = document_search.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# ' Random forest is a commonly-used machine learning algorithm used for both classification and regression tasks. It combines the output of multiple decision trees to reach a single result.'

# %%
query = "advantages of random forest"
docs = document_search.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# ' Advantages of Random Forest include out-of-bag evaluation, versatility, handling of missing data, resistance to overfitting, and the ability to handle high-dimensional datasets without needing much manual feature engineering.'

# %%
query = "describes steps how random forest work"
docs = document_search.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# ' \nRandom Forest works by performing the following steps: 1) Data preparation: Random Forest requires a dataset with input features and corresponding target variables. The data is typically split into a training set and a test set. 2) Random sampling: Random Forest performs random sampling with replacement from the training set to create multiple subsets, known as bootstrap samples. Each subset contains a random selection of data points, allowing some instances to be repeated while others may be left out. 3) Decision tree construction: For each bootstrap sample, a decision tree is constructed using recursive partitioning, where the data is split based on feature values to create branches that maximize the separation of the target variables. 4) Feature selection: At each node of the decision tree, a random subset of features is considered for splitting. This random feature selection introduces diversity among the decision trees and helps to reduce correlation. 5) Voting for predictio
# ...

# %% [markdown]
# how to query from online pdfs

# %%
from langchain.document_loaders import OnlinePDFLoader

# %%
loader = OnlinePDFLoader("https://ai.stanford.edu/~nilsson/MLBOOK.pdf")

# %%
# !pip install unstructured

# %%
# !pip install pdf2image

# %%
# !pip install pdfminer

# %%
# !pip3 install pdfminer.six

# %%
import pdfminer.high_level

# %%
data = loader.load()

# %%
data
# Out:
# [Document(page_content='INTRODUCTION\n\nTO\n\nMACHINE LEARNING\n\nAN EARLY DRAFT OF A PROPOSED\n\nTEXTBOOK\n\nNils J. Nilsson Robotics Laboratory Department of Computer Science Stanford University Stanford, CA 94305\n\ne-mail: nilsson@cs.stanford.edu\n\nNovember 3, 1998\n\nCopyright c(cid:13)2005 Nils J. Nilsson This material may not be copied, reproduced, or distributed without the written permission of the copyright holder.\n\nii\n\nContents\n\n1 Preliminaries\n\n1.1\n\nIntroduction . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 1.1.1 What is Machine Learning? . . . . . . . . . . . . . . . . . 1.1.2 Wellsprings of Machine Learning . . . . . . . . . . . . . . 1.1.3 Varieties of Machine Learning . . . . . . . . . . . . . . . . 1.2 Learning Input-Output Functions . . . . . . . . . . . . . . . . . . 1.2.1 Types of Learning . . . . . . . . . . . . . . . . . . . . . . 1.2.2 Input Vectors . . . . . . . . . . . . . . . . . . . . . . . . . 1.2.3 Outputs . . . . . . . . . . . . 
# ...

# %%
# !pip install chromadb

# %%
#openai.api_key = "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"

# %%
#embeddings = OpenAIEmbeddings(openai_api_key=openai.api_key)
embeddings = OpenAIEmbeddings()

# %%
from langchain.indexes.vectorstore import VectorstoreIndexCreator
index = VectorstoreIndexCreator().from_loaders([loader])

# %%
query = "what are the Types of Manchine Learning"
#index.query(query)
result = index.query(query)

# %%
result
# Out:
# ' Machine learning methods can be divided into three main categories: supervised learning, unsupervised learning, and reinforcement learning.'
